# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('AML_DataVisualization.csv')

# %%
df
# Out:
#         latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0      -42.69706  147.70634       333.6  0.57   0.43  2019-10-01       336
# 1      -42.26889  147.31104       336.2  0.39   0.44  2019-10-01       336
# 2      -40.85202  145.38068       327.9  0.46   0.47  2019-10-01       336
# 3      -42.39329  147.47144       346.9  0.38   0.43  2019-10-01       336
# 4      -42.69701  147.70584       334.1  0.56   0.43  2019-10-01       336
# ...          ...        ...         ...   ...    ...         ...       ...
# 956252 -32.66628  122.15253       306.9  0.39   0.44  2020-01-11      1630
# 956253 -32.58616  123.39582       299.0  0.51   0.41  2020-01-11      1630
# 956254 -33.37853  115.94735       309.7  0.40   0.60  2020-01-11      1630
# 956255 -33.21827  115.75078       300.2  0.49   0.65  2020-01-11      1806
# 956256 -33.22012  115.75043       300.3  0.49   0.65  2020-01-11      1806
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig1=plt.scatter(x=df['longitude'], y=df['latitude'])
plt.show()

# %%
# plt.plot(data1, data2, marker=".", markersize=20)
# plt.scatter(x=df['longitude'], y=df['latitude'],marker)
fig2=plt.plot(df['longitude'], df['latitude'],marker=".",markersize=1/2, alpha=1/2, ls='none')

# %%
import matplotlib.pyplot as plt
import numpy as np
 
fig3=plt.hexbin(df['longitude'], df['latitude'],bins='log',mincnt=1)
plt.colorbar()
plt.show()

# %%
fig3

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))
ax[0,0].scatter(x,y)
ax[0,0].set_title('1) With the matplotlib defaults')

ax[0,1].scatter(x, y, s=0.5, alpha=0.5)
ax[0,1].set_title('2) With marker-size 50% and alpha 50%')
                  
z =[10**0,10**1,10**2,10**3, 10**4]
im1=ax[1,0].hexbin(x, y,gridsize = 100, mincnt=1, bins=z)
ax[1, 0].set_title('3) with hexbin plot ')

num_samples = 10**4
idx = np.random.choice(np.arange(len(x)), num_samples)
ax[1,1].scatter(x[idx], y[idx]) 
ax[1,1].set_title('4) With Subsampling')

plt.colorbar(im1,ax=ax[1,0])
